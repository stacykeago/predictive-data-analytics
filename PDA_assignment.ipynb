# %% [markdown]
# <a href="https://colab.research.google.com/github/stacykeago/predictive-data-analytics/blob/main/PDA_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Define the question:

# %% [markdown]
# # Metric of success
# The likelihood of a claim being rejected could be evaluated based on several key performance indicators (KPIs) commonly used in machine learning classification tasks.
# 1. Accuracy
# 2. Precision
# 3. Recall (Sensitivity)
# 4. F1 Score
# 5. Area Under the ROC Curve (AUC-ROC)
# 6. Confusion Matrix

# %% [markdown]
# Resources that support this analysis
# 1. [Business Insights & Recommendations](https://docs.google.com/document/d/1q9gwblcG5X_Cm1P03Y4Zzbr2ue-CVVN8ecXmyi_yRAM/edit?usp=sharing)
# 2.

# %% [markdown]
# # Data used:
# 1. [link to kaggle dataset ](https://www.kaggle.com/datasets/itszubi/ai-workforce-displacement-and-automation-trends/data)

# %% [markdown]
# # a. EXPLORATTORY DATA ANALYSIS (EDA)

# %% [markdown]
# ## 1.0 Import the libraries to be used

# %%
import numpy as np # for linear algebra
import pandas as pd # for data processing
import matplotlib.pyplot as plt # for data visualization
import seaborn as sns # for statistical data visualization
from sklearn.preprocessing import LabelEncoder # the libraries for label encoding

# %% [markdown]
# ## 2.0 Upload Dataset

# %%
import kagglehub
from kagglehub import KaggleDatasetAdapter

# 1. Set the precise filename you provided
file_path = "ai_workforce_displacement_global_2020_2026.csv"

# 2. Load the dataset using kagglehub
work = kagglehub.dataset_load(
    KaggleDatasetAdapter.PANDAS,
    "itszubi/ai-workforce-displacement-and-automation-trends",
    file_path
)

# 3. View the first 5 records

work.head(10)
# Out:
# Using Colab cache for faster access to the 'ai-workforce-displacement-and-automation-trends' dataset.
#    record_id        country iso3_code         region income_group  year  \
# 0          1  United States       USA  North America  High Income  2020
# 1          2  United States       USA  North America  High Income  2020
# 2          3  United States       USA  North America  High Income  2020
# 3          4  United States       USA  North America  High Income  2020
# 4          5  United States       USA  North America  High Income  2020
# 5          6  United States       USA  North America  High Income  2020
# 6          7  United States       USA  North America  High Income  2020
# 7          8  United States       USA  North America  High Income  2020
# 8          9  United States       USA  North America  High Income  2020
# 9         10  United States       USA  North America  High Income  2020
#
#    quarter quarter_label             industry_sector  \
# ...

# %% [markdown]
# ### Column names

# %%
work.columns
# Out:
# Index(['record_id', 'country', 'iso3_code', 'region', 'income_group', 'year',
#        'quarter', 'quarter_label', 'industry_sector',
#        'sector_automation_risk_score', 'gdp_per_capita_usd',
#        'ai_adoption_index', 'pct_sector_workforce_displaced',
#        'pct_sector_workforce_new_roles_created', 'net_workforce_change_pct',
#        'ai_cited_layoff_announcements', 'ai_skill_wage_premium_pct',
#        'pct_workforce_female', 'pct_displaced_roles_female',
#        'reskilling_programs_count', 'govt_ai_policy_score_1_to_10',
#        'ai_tool_adoption_pct', 'data_source_notes'],
#       dtype='object')

# %% [markdown]
# ### 2.1 Number of rows and columns

# %%
# Print number of rows and columns
print(f"Rows: {work.shape[0]}, Columns: {work.shape[1]}")
# Out:
# Rows: 20800, Columns: 23

# %% [markdown]
# ### 2.2 Data types in each column

# %%
work.dtypes
# Out:
# record_id                                   int64
# country                                    object
# iso3_code                                  object
# region                                     object
# income_group                               object
# year                                        int64
# quarter                                     int64
# quarter_label                              object
# industry_sector                            object
# sector_automation_risk_score              float64
# gdp_per_capita_usd                          int64
# ai_adoption_index                         float64
# pct_sector_workforce_displaced            float64
# pct_sector_workforce_new_roles_created    float64
# net_workforce_change_pct                  float64
# ai_cited_layoff_announcements               int64
# ai_skill_wage_premium_pct                 float64
# pct_workforce_female                      float64
# pct_displaced_roles_female                float64
# ...

# %% [markdown]
# ### 2.3 Basic info of the data

# %%
# Display basic information about the columns
print(work.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20800 entries, 0 to 20799
# Data columns (total 23 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   record_id                               20800 non-null  int64
#  1   country                                 20800 non-null  object
#  2   iso3_code                               20800 non-null  object
#  3   region                                  20800 non-null  object
#  4   income_group                            20800 non-null  object
#  5   year                                    20800 non-null  int64
#  6   quarter                                 20800 non-null  int64
#  7   quarter_label                           20800 non-null  object
#  8   industry_sector                         20800 non-null  object
#  9   sector_automation_risk_score            20800 non-null  float64
# ...

# %% [markdown]
# ### 2.4 Null values

# %%
# To check for Null values to ensures the integrity of your dataset.
work.isnull().sum()
# Out:
# record_id                                 0
# country                                   0
# iso3_code                                 0
# region                                    0
# income_group                              0
# year                                      0
# quarter                                   0
# quarter_label                             0
# industry_sector                           0
# sector_automation_risk_score              0
# gdp_per_capita_usd                        0
# ai_adoption_index                         0
# pct_sector_workforce_displaced            0
# pct_sector_workforce_new_roles_created    0
# net_workforce_change_pct                  0
# ai_cited_layoff_announcements             0
# ai_skill_wage_premium_pct                 0
# pct_workforce_female                      0
# pct_displaced_roles_female                0
# reskilling_programs_count                 0
# govt_ai_policy_score_1_to_10              0
# ...

# %% [markdown]
# No null values in the auto dataset

# %% [markdown]
# ### 2.5 Duplicates

# %%
#check for duplicates : Duplicates are noise to the data
np.sum(work.duplicated())
# Out:
# np.int64(0)

# %% [markdown]
# ### 2.6 Unique features in the data

# %%
# count of unique values for each column in the DataFrame.
work.nunique()
# Out:
# record_id                                 20800
# country                                      80
# iso3_code                                    80
# region                                       12
# income_group                                  4
# year                                          7
# quarter                                       4
# quarter_label                                26
# industry_sector                              10
# sector_automation_risk_score                679
# gdp_per_capita_usd                         1981
# ai_adoption_index                           775
# pct_sector_workforce_displaced             2068
# pct_sector_workforce_new_roles_created     1680
# net_workforce_change_pct                    837
# ai_cited_layoff_announcements               519
# ai_skill_wage_premium_pct                   490
# pct_workforce_female                         10
# pct_displaced_roles_female                  453
# reskilling_programs_count                    91
# ...

# %% [markdown]
# ### 2.7 Outliers

# %% [markdown]
# # b. Univariate Analysis

# %% [markdown]
# # c. Bivariate Analysis

# %% [markdown]
# # d. Multivariate Analysis

# %% [markdown]
# ## Feature selection
# • What features seem most related to price?

# %% [markdown]
# # HYPOTHESIS TESTING
# 1. Does higher horsepower always mean higher price?
